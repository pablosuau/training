# %%
import os, sys
import numpy as np
util_dir = os.path.dirname('../../util/')
sys.path.insert(0, util_dir) 
from bern_beta import bern_beta

# %%
# Specify the prior:
t = 0.75 # Specify the prior MODE.
n = 25 # Specify the effective prior sample size.
a = t * (n - 2) + 1 # Convert to beta shape parameter a
b = (1 - t) * (n - 2) + 1 # Convert to beta shape parameter b

prior = [a,b] # Specify prior as vector with the two shape parameters.

# Specify the data:
N = 20 # The total number of flips.
z = 17 # The number of heads.
# Convert N and z into vector of 0's and 1's.
data = np.concatenate((np.repeat(0, N - z), np.repeat(1, z)), axis = None) 

posterior = bern_beta(prior_beta_ab = prior, 
                      data = data , 
                      plot_type = 'bars', 
                      show_cent_tend = 'mode' , 
                      show_hdi = True, 
                      show_p_d = False )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-632e1a02f522> in <module>()
#      18                       show_cent_tend = 'mode' ,
#      19                       show_hdi = True,
# ---> 20                       show_p_d = False )
#
# ~/Desktop/Data/git/training/bayesian/01_doing_bayesian_data_analysis/util/bern_beta.py in bern_beta(prior_beta_ab, data, plot_type, show_cent_tend, show_hdi, hdi_mass, show_p_d)
#      91     # Mark the highest density interval. HDI points are not thinned in the plot
#      92     if (show_hdi):
# ---> 93         [indexes, mass, height] = hdi_of_grid(p_theta, hdi_mass)
#      94         text = '{0:.2f}% HDI'.format(100 * mass)
#      95         ax[0].text(np.mean(theta[indexes]),
#
# NameError: name 'hdi_of_grid' is not defined
