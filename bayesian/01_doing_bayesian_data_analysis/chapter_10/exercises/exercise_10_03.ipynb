# %%
# %matplotlib inline
import os
os.chdir('../../util/')
import numpy as np
np.random.seed(3)

# %% [markdown]
# **Exercise 10.3. [Purpose: To get some hands-on experience with pseudo-priors.]**
#
# **(A)** Use the script `Jags-Ydich-Xnom1subj-MbernBetaModelCompPseudoPrior.R` to reproduce Figures 10.5 and 10.6. That is, run the script once with the pseudo-prior set to the true prior, and then again with the pseudo-prior set to the values shown in the text. Include the graphical output of the chain diagnostics on the model index. Your results will differ slightly from Figures 10.5 and 10.6 because of randomness in the MCMC chain.

# %%
# Without pseudopriors
with open('jags_ydich_xnom1subj_mbernbetamodelcomppseudoprior.py', 'r') as f:
    code = ''.join(f.readlines())
code = code.replace('kappa1_prior = np.array([20, 50])', 'kappa1_prior = np.array([20, 20])')
code = code.replace('omega1_prior = np.array([0.1, 0.4])', 'omega1_prior = np.array([0.1, 0.1])')
code = code.replace('kappa2_prior = np.array([50, 20])', 'kappa2_prior = np.array([20, 20])')
code = code.replace('omega2_prior = np.array([0.7, 0.9])', 'omega2_prior = np.array([0.9, 0.9])')
exec(''.join(code))
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >BinaryGibbsMetropolis: [m]
# >NUTS: [theta2, theta1]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14000' class='' max='14000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [14000/14000 00:07<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_500 draw iterations (4_000 + 10_000 draws total) took 20 seconds.
# ...

# %%
# With pseudopriors
with open('jags_ydich_xnom1subj_mbernbetamodelcomppseudoprior.py', 'r') as f:
    code = ''.join(f.readlines())
exec(''.join(code))
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >BinaryGibbsMetropolis: [m]
# >NUTS: [theta2, theta1]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14000' class='' max='14000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [14000/14000 00:06<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_500 draw iterations (4_000 + 10_000 draws total) took 18 seconds.
# ...

# %% [markdown]
# **(B)** Change the pseudo-prior to broad distributions, with `omega1[2]=omega2[1]=0.5` and `kappa1[2]=kappa[2]=2.1`. Run the script and report the results, including the chain diagnostic on the model index. Discuss.
