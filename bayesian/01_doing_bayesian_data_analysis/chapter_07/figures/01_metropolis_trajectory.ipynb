# %%
# %matplotlib inline

import os, sys
import matplotlib.pyplot as plt
util_dir = os.path.dirname('../../util/')
sys.path.insert(0, util_dir) 
from bern_metrop import bern_metrop

# %% [markdown]
# **Figure 7.4** Metropolis algorithm applied to Bernoulli likelihood with beta($\theta$|1, 1) prior and z = 14 with N = 20. For each of the three columns, there are 50000 steps in the chain, but for the top section, the proposal standard deviation (SD) is 0.02, for the middle section SD = 0.2, and for the bottom section SD = 2.0/

# %%
bern_metrop(0.02)

# %%
bern_metrop(0.2)

# %%
bern_metrop(2)

# %% [markdown]
# The results are very similar to those in Figure 7.4.
