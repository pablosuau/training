# %%
import os, sys
import numpy as np
util_dir = os.path.dirname('../../util/')
sys.path.insert(0, util_dir) 
from bern_grid import bern_grid

# %%
# Sparse teeth for theta
theta = np.linspace(0 , 1 , 5)  
# Triangular shape for p_theta
p_theta = np.minimum(theta, 1 - theta) 
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta)    
# Single flip with 1 head
data = np.concatenate((np.repeat(0, 0), np.repeat(1, 1)), axis = None)

posterior = bern_grid(theta, 
                      p_theta, 
                      data, 
                      plot_type = 'bars', 
                      show_cent_tend = 'none', 
                      show_hdi = False,
                      show_pd = False)

# %%
# Sparse teeth for theta
theta = np.linspace(0 , 1 , 11)  
# Triangular shape for p_theta
p_theta = np.minimum(theta, 1 - theta) 
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta)    
# Single flip with 1 head
data = np.concatenate((np.repeat(0, 0), np.repeat(1, 1)), axis = None)

posterior = bern_grid(theta, 
                      p_theta, 
                      data, 
                      plot_type = 'bars', 
                      show_cent_tend = 'none', 
                      show_hdi = False,
                      show_pd = False)

# %%
# Sparse teeth for theta
theta = np.linspace(0 , 1 , 1000)  
# Triangular shape for p_theta
p_theta = np.minimum(theta, 1 - theta) 
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta)    
# Single flip with 1 head
data = np.concatenate((np.repeat(0, 0), np.repeat(1, 1)), axis = None)

posterior = bern_grid(theta, 
                      p_theta, 
                      data, 
                      plot_type = 'bars', 
                      show_cent_tend = 'none', 
                      show_hdi = False,
                      show_pd = False)

# %%
# Sparse teeth for theta
theta = np.linspace(0 , 1 , 1000)  
# Triangular shape for p_theta
p_theta = np.zeros(len(theta.tolist()))
p_theta[1] = 1
p_theta[-2] = 1
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta)    
# Single flip with 1 head
data = np.concatenate((np.repeat(0, 0), np.repeat(1, 1)), axis = None)

posterior = bern_grid(theta, 
                      p_theta, 
                      data, 
                      plot_type = 'bars', 
                      show_cent_tend = 'none', 
                      show_hdi = False,
                      show_pd = False)

# %%
# Sparse teeth for theta
theta = np.linspace(0 , 1 , 1000)  
# Triangular shape for p_theta
p_theta = np.minimum(theta, 1 - theta) 
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta)    
# 25% heads, N = 4
data = np.concatenate((np.repeat(0, 3), np.repeat(1, 1)), axis = None)

posterior = bern_grid(theta, 
                      p_theta, 
                      data, 
                      plot_type = 'bars', 
                      show_cent_tend = 'mode', 
                      show_hdi = True,
                      show_pd = False)

# %%
# Sparse teeth for theta
theta = np.linspace(0 , 1 , 1000)  
# Triangular shape for p_theta
p_theta = np.minimum(theta, 1 - theta) 
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta) 
# Sharpen p_theta
p_theta = np.power(p_theta, 10)
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta)
# 25% heads, N = 4
data = np.concatenate((np.repeat(0, 3), np.repeat(1, 1)), axis = None)

posterior = bern_grid(theta, 
                      p_theta, 
                      data, 
                      plot_type = 'bars', 
                      show_cent_tend = 'mode', 
                      show_hdi = True,
                      show_pd = False)

# %%
# Sparse teeth for theta
theta = np.linspace(0 , 1 , 1000)  
# Triangular shape for p_theta
p_theta = np.minimum(theta, 1 - theta) 
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta) 
# Flatten p_theta
p_theta = np.power(p_theta, 0.1)
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta)
# 25% heads, N = 4
data = np.concatenate((np.repeat(0, 3), np.repeat(1, 1)), axis = None)

posterior = bern_grid(theta, 
                      p_theta, 
                      data, 
                      plot_type = 'bars', 
                      show_cent_tend = 'mode', 
                      show_hdi = True,
                      show_pd = False)

# %%
# Sparse teeth for theta
theta = np.linspace(0 , 1 , 1000)  
# Triangular shape for p_theta
p_theta = np.minimum(theta, 1 - theta) 
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta)
# 25% heads, N = 40
data = np.concatenate((np.repeat(0, 30), np.repeat(1, 10)), axis = None)

posterior = bern_grid(theta, 
                      p_theta, 
                      data, 
                      plot_type = 'bars', 
                      show_cent_tend = 'mode', 
                      show_hdi = True,
                      show_pd = False)

# %%
# Sparse teeth for theta
theta = np.linspace(0 , 1 , 1000)  
# Triangular shape for p_theta
p_theta = np.minimum(theta, 1 - theta) 
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta) 
# Sharpen p_theta
p_theta = np.power(p_theta, 10)
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta)
# 25% heads, N = 40
data = np.concatenate((np.repeat(0, 30), np.repeat(1, 10)), axis = None)

posterior = bern_grid(theta, 
                      p_theta, 
                      data, 
                      plot_type = 'bars', 
                      show_cent_tend = 'mode', 
                      show_hdi = True,
                      show_pd = False)

# %%
# Sparse teeth for theta
theta = np.linspace(0 , 1 , 1000)  
# Triangular shape for p_theta
p_theta = np.minimum(theta, 1 - theta) 
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta) 
# Flatten p_theta
p_theta = np.power(p_theta, 0.1)
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta)
# 25% heads, N = 40
data = np.concatenate((np.repeat(0, 30), np.repeat(1, 10)), axis = None)

posterior = bern_grid(theta, 
                      p_theta, 
                      data, 
                      plot_type = 'bars', 
                      show_cent_tend = 'mode', 
                      show_hdi = True,
                      show_pd = False)

# %%
# Sparse teeth for theta
theta = np.linspace(0 , 1 , 1000)  
# Two triangular peaks on a small non-zero floor
p_theta = np.concatenate((np.repeat(1, 200),
                          np.linspace(1, 100, 50),
                          np.linspace(100, 1, 50),
                          np.repeat(1, 200),
                          np.repeat(1, 200),
                          np.linspace(1, 100, 50),
                          np.linspace(100, 1, 50),
                          np.repeat(1, 200)), 
                         axis = None)
# Make p_theta sum to 1.0
p_theta = p_theta / np.sum(p_theta)

data = np.concatenate((np.repeat(0, 13), np.repeat(1, 14)), axis = None)

posterior = bern_grid(theta, 
                      p_theta, 
                      data, 
                      plot_type = 'bars', 
                      show_cent_tend = 'mode', 
                      show_hdi = True,
                      show_pd = False)

# %%
# ------
# TODO: 
# Add comments to the plots in this notebook to identify them with the corresponding figure in the book
# commit
# integral of density.R and use it from figures in chapter 4 instead of duplicating the code there
# commit
# exercises
# adapt the text to gitbook and anki cards
