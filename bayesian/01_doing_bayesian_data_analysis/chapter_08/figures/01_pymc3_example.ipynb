# %%
# %matplotlib inline

import os
import numpy as np
import matplotlib.pyplot as plt
os.chdir('../../util/')
np.random.seed(2)
import jags_example_script
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 4 jobs)
# NUTS: [theta]
# Sampling 3 chains: 100%|██████████| 11502/11502 [00:03<00:00, 3749.57draws/s]
# The acceptance probability does not match the target. It is 0.8802289927909716, but should be close to 0.8. Try to increase the number of tuning steps.
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)

# %% [markdown]
# **Figure 8.3** Convergence diagnostics for input of PyMC3 (top four plots)
#
# **Figure 8.4** Posterior distribution based on output from PyMC3, pltted twice using different options in the `plot_post` function (bottom two plots)
