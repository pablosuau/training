# %%
# %matplotlib inline

import os
import numpy as np
import matplotlib.pyplot as plt
os.chdir('../../util/')
np.random.seed(2)
from jags_ydich_xnomssubj_mbernbeta_example import jags_ydich_xnomssubj_mbernbeta_example
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# **Exercise 8.1. [Purpose: Run the high level scripts with other data to see how easy they are.]** Consider the high-level script, `jags_ydich_xnomssubj_mberbeta_example.py`. For this exercise, you will use that script with a new data file, and notice that you only need to change a single line, namely the one that loads the data file.
#
# Open a new blank file. Manually type in new fictional data in the same format as the data shown in Section 8.4, p.208, but with three subjects instead of two. Use whatever names you fancy, and as many trials for each subject as you fancy. Perhaps put a preponderance of 0's for one subject and relatively few trials for another. Save the file with a filename that ends with `.csv`. Then, in the script, use that file name in the command to read the csv file. In your report, include the data file and the graphical output of the analysis. Are the estimates reasonable? What is the effect of different sample sizes for the estimates of different subjects?

# %%
# Generating the new file
file_contents = '''"y","s"
"1","Garfield"
"0","Garfield"
"0","Garfield"
"0","Garfield"
"0","Garfield"
"0","Garfield"
"1","Garfield"
"0","Garfield"
"0","Garfield"
"0","Garfield"
"1","Garfield"
"0","Garfield"
"0","Garfield"
"1","Garfield"
"0","Garfield"
"0","Garfield"
"0","Garfield"
"1","Garfield"
"0","Odie"
"1","Odie"
"1","Odie"
"1","Odie"
'''

# %%
with open('exercise_8_01.csv', 'w') as f:
    f.write(file_contents)

# %%
# Running the example script using the file designed for this exercise
jags_ydich_xnomssubj_mbernbeta_example('exercise_8_01.csv')
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [theta_2, theta_1]
# Sampling 4 chains: 100%|██████████| 52000/52000 [00:13<00:00, 3815.23draws/s]
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)

# %% [markdown]
# The only noticeable difference when we take samples with different sizes since to be on the width of the posterior for each individual parameter (theta_1 vs. theta_2). In my example, the sample for theta_2 is smaller, and its corresponding posterior is wider than that of theta_1. However, the posterior distribution's width for the theta_2-theta_2 random variable seems to be closer to theta_1's one than to theta_2's.
#
# The statistics used to diagnose the traces for both theta_1 and theta_2 are quite similar, in spite of the difference in sample size, given the fact that we are sampling the same number of values of the posterior for both theta_1 and theta_2.

# %%
os.remove('exercise_8_01.csv')
