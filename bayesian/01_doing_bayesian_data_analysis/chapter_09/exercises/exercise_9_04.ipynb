# %%
import os
import inspect
os.chdir('../../util/')
import jags_ydich_xnomssubj_mbinombetaomegakappa_example

# %% [markdown]
# **Exercise 9.4. [Purpose: Explore duration of processing by JAGS]** Consider the therapeutic touch data of Figure 9.9, as analyzed by the program `Jags-Ydich-XnomSsubj-MbinomBetaOmegaKappa.R`. Open that program in RStudio and find the section that calls `runjags` or `rjags`.
#
# **(A)** Set the program (if it is not already) to use three parallel chains with `runjags`. Be sure to save the program after any changes. Then run the high-level script, `Jags-Ydich-XnomSSubj-MbinomBetaOmegaKappa-Example.R`. Be sure it has `proc.time()` before and after `genMCMC` so that you can monitor how long it takes to generate the MCMC chain. Report the elapsed time of the chain generation, and also include the chain-diagnostic graph of omega, which includes its ESS.

# %%
func = inspect.getsource(jags_ydich_xnomssubj_mbinombetaomegakappa_example)
func = func.replace('num_saved_steps = 20000,', 
                    'num_saved_steps = 20000, n_chains = 4,')
exec(func, jags_ydich_xnomssubj_mbinombetaomegakappa_example.__dict__)
jags_ydich_xnomssubj_mbinombetaomegakappa_example.jags_ydich_xnomssubj_mbinombetaomegakappa_example()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [thetas, kappa_minus_two, omega]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='204000' class='' max='204000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [204000/204000 02:31<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# ...

# %% [markdown]
# **(B)** Set the program `Ydich-XnomSsubj-MbinomBetaOmegaKappa.R` to use `rjags` (with a single long chain. Be sure to save the program after any changes. Then un the high level script, `Jags-Ydich-XnomSSubj-MbinomBetaOmegaKappa-Example.R`. Be sure it has `proc.time()` before and after `genMCMC` so that you can monitor how long it takes to generate the MCMC chain. Report the elapsed time of the chain generation, and also include the chain-diagnostic graph of omega, which include its ESS.

# %%
func = inspect.getsource(jags_ydich_xnomssubj_mbinombetaomegakappa_example)
func = func.replace('num_saved_steps = 20000,', 
                    'num_saved_steps = 20000, n_chains = 2,')
exec(func, jags_ydich_xnomssubj_mbinombetaomegakappa_example.__dict__)
jags_ydich_xnomssubj_mbinombetaomegakappa_example.jags_ydich_xnomssubj_mbinombetaomegakappa_example()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [thetas, kappa_minus_two, omega]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='202000' class='' max='202000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [202000/202000 03:19<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# ...

# %% [markdown]
# **(C)** Compare the two runs. What is the difference in run durations? Are the ESS about the same?
#
# I didn't need to make any changes to the code to measure the execution time of the chains. The aim of this exercise is to see the impact of the number of chains on the execution time (that's why in the second part of the exercise I use two chains instead of one - it makes things faster and I was getting an error with a single chain.)
#
# Using 4 chains to generate the chain takes 2:31 vs. 3:14 when we use 2 chains, and there is not much difference in terms of ESS (86002 vs 91482).
